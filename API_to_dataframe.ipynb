# %%
import pandas as pd
import requests

# %%
 response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=0574eaab6dd93d263849a8090fa2d73a&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     182.311
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     196.159
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     107.942
# 3  The true story of how businessman Oskar Schind...   1993-12-15     137.543
# 4  The defense and the prosecution have rested an...   1957-04-10      74.962
#
#    vote_average  vote_count
# 0         8.700       27572
# 1         8.700       20919
# 2         8.600       12620
# 3         8.567       16063
# 4         8.500        8812

# %%
#Creating empty dataframe
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,497):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=0574eaab6dd93d263849a8090fa2d73a&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.shape
# Out:
# (9915, 7)

# %%
df.to_csv('TopRated_movies.csv')
